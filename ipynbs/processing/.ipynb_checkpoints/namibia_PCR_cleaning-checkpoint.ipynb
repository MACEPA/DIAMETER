# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
npcr = pd.read_csv('C:/Users/lzoeckler/Desktop/namibia_PCR/HRP2 persistence study data for PATH_27Jan2020.csv')
npcr.head()
# Out:
#     pa_id  age     sex  day0_enrollee  days_since_detection_enroll  \
# 0  PA-001    2  Female              1                            0
# 1  PA-002   80  Female              1                            0
# 2  PA-003   23  Female              0                            5
# 3  PA-004   17  Female              1                            0
# 4  PA-005   21    Male              1                            0
#
#    time_to_negativity_urdt   where_detected enroll_hrp2_pg_ml d3_hrp2_pg_ml  \
# 0                       29  Health Facility               NaN     318702.59
# 1                       35  Health Facility       43928722.05     930087.39
# 2                       66  Health Facility         251849.37           NaN
# 3                       56  Health Facility           46391.5         12.11
# 4                       71  Health Facility         7872641.8           NaN
#
#   d7_hrp2_pg_ml  ... d70_qpcr_p_density d77_qpcr_p_density d84_qpcr_p_density  \
# 0      73737.79  ...                NaN                NaN                NaN
# 1     179497.76  ...                NaN                NaN                NaN
# 2           NaN  ...                NaN                NaN                NaN
# 3           NaN  ...                NaN                NaN                NaN
# 4     391686.21  ...                NaN                NaN                NaN
#
#   d91_qpcr_p_density d98_qpcr_p_density d105_qpcr_p_density  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#   d112_qpcr_p_density d119_qpcr_p_density d126_qpcr_p_density  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#   d133_qpcr_p_density
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 49 columns]

# %%
core_cols = ['pa_id', 'age', 'sex', 'day0_enrollee', 'days_since_detection_enroll',
             'time_to_negativity_urdt', 'where_detected']
hrp2_cols = [col for col in npcr.columns if 'hrp2_pg_ml' in col]
qpcr_cols = [col for col in npcr.columns if 'qpcr_p_density' in col]

# %%
hrp2_df = npcr[core_cols + hrp2_cols]
qpcr_df = npcr[core_cols + qpcr_cols]

# %%
for col in hrp2_cols:
    if 'enroll' in col:
        new_col = '0'
    else:
        new_col = col.split('_')[0]
        new_col = new_col.strip('d')
    hrp2_df.rename(columns={col: new_col}, inplace=True)
hrp2_df.head()
# Out:
# C:\Users\lzoeckler\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#     pa_id  age     sex  day0_enrollee  days_since_detection_enroll  \
# 0  PA-001    2  Female              1                            0
# 1  PA-002   80  Female              1                            0
# 2  PA-003   23  Female              0                            5
# 3  PA-004   17  Female              1                            0
# 4  PA-005   21    Male              1                            0
#
#    time_to_negativity_urdt   where_detected            0          3  \
# 0                       29  Health Facility          NaN  318702.59
# 1                       35  Health Facility  43928722.05  930087.39
# 2                       66  Health Facility    251849.37        NaN
# 3                       56  Health Facility      46391.5      12.11
# 4                       71  Health Facility    7872641.8        NaN
#
#            7  ...      70   77  84  91  98 105 112 119 126 133
# 0   73737.79  ...     NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1  179497.76  ...     NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2        NaN  ...     NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3        NaN  ...     NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4  391686.21  ...  417.55  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 28 columns]

# %%
for col in qpcr_cols:
    if 'enroll' in col:
        new_col = '0'
    else:
        new_col = col.split('_')[0]
        new_col = new_col.strip('d')
    qpcr_df.rename(columns={col: new_col}, inplace=True)
qpcr_df.head()
# Out:
#     pa_id  age     sex  day0_enrollee  days_since_detection_enroll  \
# 0  PA-001    2  Female              1                            0
# 1  PA-002   80  Female              1                            0
# 2  PA-003   23  Female              0                            5
# 3  PA-004   17  Female              1                            0
# 4  PA-005   21    Male              1                            0
#
#    time_to_negativity_urdt   where_detected   3   7     14  ...  70  77  84  \
# 0                       29  Health Facility NaN NaN    NaN  ... NaN NaN NaN
# 1                       35  Health Facility NaN NaN    NaN  ... NaN NaN NaN
# 2                       66  Health Facility NaN NaN    NaN  ... NaN NaN NaN
# 3                       56  Health Facility NaN NaN    NaN  ... NaN NaN NaN
# 4                       71  Health Facility NaN NaN  0.223  ... NaN NaN NaN
#
#    91  98  105  112  119  126  133
# 0 NaN NaN  NaN  NaN  NaN  NaN  NaN
# 1 NaN NaN  NaN  NaN  NaN  NaN  NaN
# 2 NaN NaN  NaN  NaN  NaN  NaN  NaN
# 3 NaN NaN  NaN  NaN  NaN  NaN  NaN
# 4 NaN NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 27 columns]

# %%
hrp2_vars = [col for col in hrp2_df.columns if col.isdigit()]
hrp2_df = pd.melt(hrp2_df, id_vars=core_cols, value_vars=hrp2_vars,
                  var_name='timepoint_days', value_name='hrp2_pg_ml')
hrp2_df.head()
# Out:
#     pa_id  age     sex  day0_enrollee  days_since_detection_enroll  \
# 0  PA-001    2  Female              1                            0
# 1  PA-002   80  Female              1                            0
# 2  PA-003   23  Female              0                            5
# 3  PA-004   17  Female              1                            0
# 4  PA-005   21    Male              1                            0
#
#    time_to_negativity_urdt   where_detected timepoint_days   hrp2_pg_ml
# 0                       29  Health Facility              0          NaN
# 1                       35  Health Facility              0  43928722.05
# 2                       66  Health Facility              0    251849.37
# 3                       56  Health Facility              0      46391.5
# 4                       71  Health Facility              0    7872641.8

# %%
qpcr_vars = [col for col in qpcr_df.columns if col.isdigit()]
qpcr_df = pd.melt(qpcr_df, id_vars=core_cols, value_vars=qpcr_vars,
                  var_name='timepoint_days', value_name='qpcr_p_density')
qpcr_df.head()
# Out:
#     pa_id  age     sex  day0_enrollee  days_since_detection_enroll  \
# 0  PA-001    2  Female              1                            0
# 1  PA-002   80  Female              1                            0
# 2  PA-003   23  Female              0                            5
# 3  PA-004   17  Female              1                            0
# 4  PA-005   21    Male              1                            0
#
#    time_to_negativity_urdt   where_detected timepoint_days  qpcr_p_density
# 0                       29  Health Facility              3             NaN
# 1                       35  Health Facility              3             NaN
# 2                       66  Health Facility              3             NaN
# 3                       56  Health Facility              3             NaN
# 4                       71  Health Facility              3             NaN

# %%
combo_df = pd.merge(hrp2_df, qpcr_df, how='outer')
combo_df['pa_id'] = combo_df['pa_id'].apply(str.lower)
combo_df['timepoint_days'] = combo_df['timepoint_days'].apply(int)
combo_df = combo_df.loc[~combo_df['hrp2_pg_ml'].isnull()]
combo_df.loc[combo_df['timepoint_days'] != 0, 'timepoint_days'] = combo_df['timepoint_days'].subtract(
    combo_df['days_since_detection_enroll'])
combo_df.rename(columns={'pa_id': 'participant_id', 'age': 'age_yrs', 'hrp2_pg_ml': 'quansys_HRP2_pg_ml'}, inplace=True)
combo_df.head()
# Out:
#   participant_id  age_yrs     sex  day0_enrollee  days_since_detection_enroll  \
# 1         pa-002       80  Female              1                            0
# 2         pa-003       23  Female              0                            5
# 3         pa-004       17  Female              1                            0
# 4         pa-005       21    Male              1                            0
# 5         pa-006       39  Female              0                           10
#
#    time_to_negativity_urdt   where_detected  timepoint_days  \
# 1                       35  Health Facility               0
# 2                       66  Health Facility               0
# 3                       56  Health Facility               0
# 4                       71  Health Facility               0
# 5                       30  Health Facility               0
#
#   quansys_HRP2_pg_ml  qpcr_p_density
# 1        43928722.05             NaN
# 2          251849.37             NaN
# 3            46391.5             NaN
# 4          7872641.8             NaN
# 5            1849.23             NaN

# %%
base_namib = pd.read_csv('C:/Users/lzoeckler/Desktop/all_data/separated/18-UCSF-01.csv')
base_namib = base_namib[['participant_id', 'age_yrs', 'timepoint_days', 'febrile', 'quansys_HRP2_pg_ml']]
base_namib['timepoint_days'] = base_namib['timepoint_days'].apply(int)
base_namib.head()
# Out:
#   participant_id  age_yrs  timepoint_days  febrile quansys_HRP2_pg_ml
# 0         pa-001        2              14        0            4138.79
# 1         pa-001        2              21        0            1377.18
# 2         pa-001        2              28        0            2024.41
# 3         pa-001        2               3        0          318702.59
# 4         pa-001        2               7        0           73737.79

# %%
offset_df = []
for pid in ['pa-033']:#combo_df['participant_id'].unique():
    new_sub = combo_df.loc[combo_df['participant_id'] == pid]
    base_sub = base_namib.loc[base_namib['participant_id'] == pid]
    merged = pd.merge(base_sub, new_sub, how='left', on=['participant_id', 'age_yrs', 'quansys_HRP2_pg_ml'])
    merged = merged.loc[~merged['timepoint_days_y'].isnull()]
    unequal = merged.loc[merged['timepoint_days_x'] != merged['timepoint_days_y']]
    equal_dates = merged.loc[merged['timepoint_days_x'] == merged['timepoint_days_y'], 'timepoint_days_y'].tolist()
    offsets = (unequal['timepoint_days_x'] - unequal['timepoint_days_y'])
    unique_offsets = offsets.unique().tolist()
    if len(unique_offsets) == 1:
        offset = unique_offsets[0]
        equal_sub = new_sub.loc[new_sub['timepoint_days'].isin(equal_dates)]
        unequal_sub = new_sub.loc[~new_sub['timepoint_days'].isin(equal_dates)]
        unequal_sub['timepoint_days'] = unequal_sub['timepoint_days'] + offset
        both = pd.concat([unequal_sub, equal_sub])
        offset_df.append(both)
    elif len(unique_offsets) > 1:
        print(pid)
        all_offsets = offsets.tolist()
        occurence_count = Counter(all_offsets) 
        offset = occurence_count.most_common(1)[0][0]
        print(offset)
        equal_sub = new_sub.loc[new_sub['timepoint_days'].isin(equal_dates)]
        unequal_sub = new_sub.loc[~new_sub['timepoint_days'].isin(equal_dates)]
        unequal_sub['timepoint_days'] = unequal_sub['timepoint_days'] + offset
        both = pd.concat([unequal_sub, equal_sub])
        all_days = both['timepoint_days']
        unique_days = both['timepoint_days'].unique()
        if len(all_days) != len(unique_days):
            print('check')
        offset_df.append(both)
    else:
        offset_df.append(new_sub)
offset_df = pd.concat(offset_df)
offset_df
# Out:
# pa-033
# -4.0
# check
# C:\Users\lzoeckler\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     participant_id  age_yrs   sex  day0_enrollee  days_since_detection_enroll  \
# 331         pa-033       44  Male              0                            3
# 635         pa-033       44  Male              0                            3
# 787         pa-033       44  Male              0                            3
# 27          pa-033       44  Male              0                            3
#
#      time_to_negativity_urdt   where_detected  timepoint_days  \
# 331                       30  Health Facility             0.0
# 635                       30  Health Facility            14.0
# 787                       30  Health Facility            21.0
# 27                        30  Health Facility             0.0
#
#     quansys_HRP2_pg_ml  qpcr_p_density
# 331            7065.84             NaN
# 635               4.24           0.092
# 787               4.52             NaN
# 27            11318.63             NaN

# %%
base_sub
# Out:
#     participant_id  age_yrs  timepoint_days  febrile quansys_HRP2_pg_ml
# 278         pa-033       44               0        1           11318.63
# 279         pa-033       44              14        0               4.24
# 280         pa-033       44              21        0               4.52
# 281         pa-033       44              28        0               4.31
# 282         pa-033       44               7        0            7065.84

# %%
new_sub
# Out:
#     participant_id  age_yrs   sex  day0_enrollee  days_since_detection_enroll  \
# 27          pa-033       44  Male              0                            3
# 331         pa-033       44  Male              0                            3
# 635         pa-033       44  Male              0                            3
# 787         pa-033       44  Male              0                            3
#
#      time_to_negativity_urdt   where_detected  timepoint_days  \
# 27                        30  Health Facility               0
# 331                       30  Health Facility               4
# 635                       30  Health Facility              18
# 787                       30  Health Facility              25
#
#     quansys_HRP2_pg_ml  qpcr_p_density
# 27            11318.63             NaN
# 331            7065.84             NaN
# 635               4.24           0.092
# 787               4.52             NaN

# %%
offset_df.to_csv('C:/Users/lzoeckler/Desktop/namibia_PCR/formatted_namibia_PCR.csv', index=False)

# %%
for_merge = offset_df[['participant_id', 'age_yrs', 'timepoint_days', 'quansys_HRP2_pg_ml', 'qpcr_p_density']]
for_merge['timepoint_days'] = for_merge['timepoint_days'].apply(int)
for_merge.head()
# Out:
# C:\Users\lzoeckler\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     participant_id  age_yrs  timepoint_days quansys_HRP2_pg_ml  qpcr_p_density
# 1           pa-002       80               0        43928722.05             NaN
# 153         pa-002       80               3          930087.39             NaN
# 305         pa-002       80               7          179497.76             NaN
# 457         pa-002       80              14            7748.22             NaN
# 609         pa-002       80              21             766.74             NaN

# %%
def clean_strings(val):
    if isinstance(val, str):
        if '<' in val:
            return np.log10(.1)
        elif '>' in val:
            clean = val.replace('> ', '')
            return np.log10(float(clean) + .1)
        else:
            try:
                return np.log10(float(val) + .1)
            except ValueError:
                return np.null
    elif isinstance(val, float) or isinstance(val, int):
        return np.log10(val + .1)
    else:
        raise

# %%
base_plot = base_namib[['participant_id', 'age_yrs', 'timepoint_days', 'quansys_HRP2_pg_ml']]
base_plot['quansys_HRP2_pg_ml'] = base_plot['quansys_HRP2_pg_ml'].apply(clean_strings)
base_plot.head()
# Out:
# C:\Users\lzoeckler\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   participant_id  age_yrs  timepoint_days  quansys_HRP2_pg_ml
# 0         pa-001        2              14            3.616884
# 1         pa-001        2              21            3.139022
# 2         pa-001        2              28            3.306320
# 3         pa-001        2               3            5.503386
# 4         pa-001        2               7            4.867691

# %%
merge_plot = for_merge[['participant_id', 'age_yrs', 'timepoint_days', 'quansys_HRP2_pg_ml']]
merge_plot['quansys_HRP2_pg_ml'] = merge_plot['quansys_HRP2_pg_ml'].apply(clean_strings)
merge_plot.head()
# Out:
# C:\Users\lzoeckler\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     participant_id  age_yrs  timepoint_days  quansys_HRP2_pg_ml
# 1           pa-002       80               0            7.642749
# 153         pa-002       80               3            5.968524
# 305         pa-002       80               7            5.254059
# 457         pa-002       80              14            3.889208
# 609         pa-002       80              21            2.884705

# %%
pp = PdfPages('C:/Users/lzoeckler/Desktop/nambia_compare.pdf')
for pid in base_plot['participant_id'].unique():
    base_sub = base_plot.loc[base_plot['participant_id'] == pid]
    base_sub = base_sub.loc[~base_sub['quansys_HRP2_pg_ml'].isnull()]
    merge_sub = merge_plot.loc[merge_plot['participant_id'] == pid]
    merge_sub = merge_sub.loc[~merge_sub['quansys_HRP2_pg_ml'].isnull()]
    base_sub.sort_values('timepoint_days', inplace=True)
    merge_sub.sort_values('timepoint_days', inplace=True)
    f = plt.figure()
    f.add_subplot()
    plt.plot(base_sub['timepoint_days'], base_sub['quansys_HRP2_pg_ml'],
             color='green', label='old data', alpha=0.5)
    plt.plot(merge_sub['timepoint_days'], merge_sub['quansys_HRP2_pg_ml'],
             color='red', label='new data', alpha=0.5)
    plt.title(pid)
    plt.xlabel('Timepoint, in days')
    plt.ylabel('Log10 HRP2')
    plt.tight_layout()
    plt.legend()
    plt.show()
    pp.savefig(f)
    plt.close()
pp.close()

# %%
base_plot.loc[base_plot['participant_id'] == 'pa-042']
# Out:
#     participant_id  age_yrs  timepoint_days  quansys_HRP2_pg_ml
# 374         pa-042       14               0            4.876004
# 375         pa-042       14              14            4.834728
# 376         pa-042       14              21            4.090603
# 377         pa-042       14              35            3.820430
# 378         pa-042       14              42            3.855004
# 379         pa-042       14              49            3.610060
# 380         pa-042       14              56            3.035618
# 381         pa-042       14              63            2.204147
# 382         pa-042       14               7            5.656027
# 383         pa-042       14              70            1.873437
# 384         pa-042       14              77            1.801609
# 385         pa-042       14              84            1.055760

# %%
merge_plot.loc[merge_plot['participant_id'] == 'pa-042']
# Out:
#      participant_id  age_yrs  timepoint_days  quansys_HRP2_pg_ml
# 492          pa-042       14               7            5.656027
# 644          pa-042       14              14            4.834728
# 796          pa-042       14              21            4.090603
# 1100         pa-042       14              35            3.820430
# 1252         pa-042       14              42            3.855004
# 1404         pa-042       14              49            3.610060
# 1556         pa-042       14              56            3.035618
# 1708         pa-042       14              63            2.204147
# 1860         pa-042       14              70            1.873437
# 2012         pa-042       14              77            1.801609
# 2164         pa-042       14              84            1.055760
# 36           pa-042       14               0            4.876004
