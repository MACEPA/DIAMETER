# %%
import pandas as pd

# %%
all_dex = pd.read_excel('C:/Users/lzoeckler/Desktop/all_data/DexQueryData.xlsx')
all_dex.head()
# Out:
#      study_id       sample_id participant_id sample_type  \
# 0  16-SMRU-01  1 110501023 ()      110501023  WB
# 1  16-SMRU-01    1 1421001 ()        1421001  WB
# 2  16-SMRU-01    1 1421035 ()        1421035  WB
# 3  16-SMRU-01     1 151019 ()         151019  WB
# 4  16-SMRU-01    1 1771028 ()        1771028  WB
#
#                                              country  lat  long  age_yrs  \
# 0  Myanmar                                       ...  NaN   NaN      NaN
# 1  Myanmar                                       ...  NaN   NaN      NaN
# 2  Myanmar                                       ...  NaN   NaN      NaN
# 3  Myanmar                                       ...  NaN   NaN      NaN
# 4  Myanmar                                       ...  NaN   NaN      NaN
#
#    timepoint_days  febrile  ... quansys_LDH_Pan_pg_ml quansys_LDH_Pv_pg_ml  \
# 0             NaN      0.0  ...               < 14.41               < 2.33
# ...

# %%
for study_id in all_dex['study_id'].unique():
    study_df = all_dex.loc[all_dex['study_id'] == study_id]
    study_df.to_csv('C:/Users/lzoeckler/Desktop/all_data/separated/{}.csv'.format(study_id))
