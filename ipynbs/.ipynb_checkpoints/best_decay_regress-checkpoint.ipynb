# %%
import pandas as pd
import math
from functools import reduce
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
pd.set_option('chained_assignment',None)

# %%
main_df = pd.read_excel('C:/Users/lzoeckler/Desktop/decay/DBS_stability_2.xlsx')
main_df.rename(columns={'Unnamed: 0': 'analyte', 'Unnamed: 1': 'treatment_condition',
                       'Unnamed: 2': 'time_or_humidity'}, inplace=True)
main_df.loc[main_df['analyte'] == 'Pv LDH', 'analyte'] = 'Pv_LDH'
main_df.loc[main_df['analyte'] == 'Pf LDH', 'analyte'] = 'Pf_LDH'
main_df.head()
# Out:
#   analyte treatment_condition  time_or_humidity       Hi     Med    Low
# 0    HRP2               -20oC               1.0  1546.99  806.53  79.33
# 1    HRP2               -20oC               3.0  1300.62  791.51  64.99
# 2    HRP2               -20oC               7.0  1582.84  897.24  88.90
# 3    HRP2               -20oC              15.0  1547.39  691.08  67.17
# 4    HRP2               -20oC              30.0  1648.93  927.27  93.60

# %%
main_df['analyte'].unique()
# Out:
# array(['HRP2', 'Pv_LDH', 'Pf_LDH', 'CRP'], dtype=object)

# %%
def temp_adjust(df):
    temp = df['treatment_condition']
    temp = temp.replace("oC", "")
    temp = int(temp)
    return temp

# %%
time_df = main_df.loc[main_df['treatment_condition'] != 'Humidity']
time_df['treatment_condition'] = time_df.apply(temp_adjust, axis=1)
time_df['treatment_condition'].unique()
# Out:
# array([-20,   4,  23,  30,  50], dtype=int64)

# %%
time_df['time_or_humidity'].unique()
# Out:
# array([  1.,   3.,   7.,  15.,  30.,  60., 120., 240.])

# %%
time_df.loc[(time_df['treatment_condition'] == 4)
            & (time_df['analyte'] == 'Pf_LDH')]
# Out:
#    analyte  treatment_condition  time_or_humidity        Hi      Med      Low
# 48  Pf_LDH                    4               1.0  14046.28  8512.34   699.70
# 49  Pf_LDH                    4               3.0  10830.68  6827.24   733.67
# 50  Pf_LDH                    4               7.0  12851.85  6780.80  1020.71
# 51  Pf_LDH                    4              15.0  10828.34  6620.00   717.24
# 52  Pf_LDH                    4              30.0  11073.76  7259.36   726.47
# 53  Pf_LDH                    4              60.0   9051.57  6087.39   734.50
# 54  Pf_LDH                    4             120.0  10267.39  5463.79   567.97
# 55  Pf_LDH                    4             240.0   8830.77  5670.04   642.13

# %%
base_value_df = time_df.loc[time_df['treatment_condition'] == -20]
base_value_df = base_value_df.groupby(['analyte', 'treatment_condition']).mean().reset_index()
base_value_df.drop(['treatment_condition', 'time_or_humidity'], axis=1, inplace=True)
base_value_df
# Out:
#   analyte           Hi         Med        Low
# 0     CRP  17950.92500  7628.23500  699.82500
# 1    HRP2   1534.43625   825.94375   83.70375
# 2  Pf_LDH  12022.15500  6948.41500  796.22750
# 3  Pv_LDH   4976.20875  2897.74000  312.14625

# %%
time_df = time_df.loc[time_df['treatment_condition'] != -20]
time_df = time_df.merge(base_value_df, on='analyte', suffixes=('', '_base'))
time_df.head()
# Out:
#   analyte  treatment_condition  time_or_humidity       Hi      Med     Low  \
# 0    HRP2                    4               1.0  1937.11  1006.40   79.08
# 1    HRP2                    4               3.0  1438.96   875.57   76.59
# 2    HRP2                    4               7.0  1748.31   945.54  105.97
# 3    HRP2                    4              15.0  1563.24   809.20   73.14
# 4    HRP2                    4              30.0  1716.19  1039.20  222.44
#
#       Hi_base   Med_base  Low_base
# 0  1534.43625  825.94375  83.70375
# 1  1534.43625  825.94375  83.70375
# 2  1534.43625  825.94375  83.70375
# 3  1534.43625  825.94375  83.70375
# 4  1534.43625  825.94375  83.70375

# %%
test_df = time_df.copy(deep=True)
#test_df = test_df.loc[test_df['time_or_humidity'] > 15]
for analyte in time_df['analyte'].unique():
    an_df = test_df.loc[time_df['analyte'] == analyte]
    for concentration in ['Hi', 'Med', 'Low']:
        con_df = an_df[['treatment_condition', 'time_or_humidity',
                        concentration, '{}_base'.format(concentration)]]
        end_df = con_df.loc[con_df['time_or_humidity'] == 240.0]
        end_df['decay'] = True
        end_df.loc[end_df[concentration] > end_df['{}_base'.format(concentration)], 'decay'] = False
        end_df.drop(['time_or_humidity', concentration, '{}_base'.format(concentration)], axis=1, inplace=True)
        con_df = con_df.merge(end_df, on=['treatment_condition'])
        calc_df = con_df.loc[con_df['decay'] == True]
        base_val = calc_df['{}_base'.format(concentration)].tolist()[0]
        for temp in calc_df['treatment_condition'].unique():
            temp_df = calc_df.loc[calc_df['treatment_condition'] == temp]
            temp_df.drop(['decay', 'treatment_condition', '{}_base'.format(concentration)], axis=1, inplace=True)
            poly = PolynomialFeatures(degree=4)
            regr = linear_model.LinearRegression()
            time = temp_df['time_or_humidity'].values.reshape(-1,1)
            con = temp_df[concentration].values.reshape(-1,1)
            poly_time = poly.fit_transform(time)
            regr.fit(poly_time, con)
            pred = regr.predict(poly_time)
            plt.scatter(time, con)
            plt.plot(time, pred, color='red')
            plt.show()
            closest_difference = 1000000000
            close_time = 'FAIL'
            best_half = 'FAIL'
            for value in range(0, 400):
                guess = regr.predict(poly.fit_transform([[value]]))
                difference = abs((base_val / 2) - guess)
                if difference < closest_difference:
                    closest_difference = difference
                    close_time = value
                    best_half = guess
            print("analyte: {}, concentration: {}, temp: {}, base_half: {}, closest_val: {}, half life: {}".format(
            analyte, concentration, temp, (base_val / 2), best_half, close_time))
# Out:
# analyte: HRP2, concentration: Hi, temp: 23, base_half: 767.2181250000001, closest_val: [[848.70873997]], half life: 184
# analyte: HRP2, concentration: Hi, temp: 30, base_half: 767.2181250000001, closest_val: [[769.1705223]], half life: 246
# analyte: HRP2, concentration: Hi, temp: 50, base_half: 767.2181250000001, closest_val: [[767.74956366]], half life: 95
# analyte: HRP2, concentration: Med, temp: 23, base_half: 412.97187499999995, closest_val: [[416.5233655]], half life: 249
# analyte: HRP2, concentration: Med, temp: 30, base_half: 412.97187499999995, closest_val: [[416.72670594]], half life: 255
# analyte: HRP2, concentration: Med, temp: 50, base_half: 412.97187499999995, closest_val: [[413.36707202]], half life: 54
# analyte: HRP2, concentration: Low, temp: 23, base_half: 41.851875, closest_val: [[41.60863855]], half life: 254
# analyte: HRP2, concentration: Low, temp: 30, base_half: 41.851875, closest_val: [[41.62009479]], half life: 277
# analyte: HRP2, concentration: Low, temp: 50, base_half: 41.851875, closest_val: [[42.06103867]], half life: 70
# analyte: Pv_LDH, concentration: Hi, temp: 4, base_half: 2488.104375, closest_val: [[3547.62933981]], half life: 209
# analyte: Pv_LDH, concentration: Hi, temp: 23, base_half: 2488.104375, closest_val: [[2493.69819003]], half life: 153
# analyte: Pv_LDH, concentration: Hi, temp: 30, base_half: 2488.104375, closest_val: [[2481.70598895]], half life: 274
# analyte: Pv_LDH, concentration: Hi, temp: 50, base_half: 2488.104375, closest_val: [[2508.54245292]], half life: 9
# analyte: Pv_LDH, concentration: Med, temp: 4, base_half: 1448.8700000000001, closest_val: [[1456.15629492]], half life: 156
# analyte: Pv_LDH, concentration: Med, temp: 23, base_half: 1448.8700000000001, closest_val: [[1448.92321635]], half life: 201
# analyte: Pv_LDH, concentration: Med, temp: 30, base_half: 1448.8700000000001, closest_val: [[1451.95386936]], half life: 19
# analyte: Pv_LDH, concentration: Med, temp: 50, base_half: 1448.8700000000001, closest_val: [[1470.69493214]], half life: 9
# analyte: Pv_LDH, concentration: Low, temp: 4, base_half: 156.073125, closest_val: [[156.46634731]], half life: 151
# analyte: Pv_LDH, concentration: Low, temp: 23, base_half: 156.073125, closest_val: [[156.16379455]], half life: 75
# analyte: Pv_LDH, concentration: Low, temp: 30, base_half: 156.073125, closest_val: [[155.89702888]], half life: 42
# analyte: Pv_LDH, concentration: Low, temp: 50, base_half: 156.073125, closest_val: [[156.13385817]], half life: 5
# analyte: Pf_LDH, concentration: Hi, temp: 4, base_half: 6011.077499999999, closest_val: [[5996.61585804]], half life: 253
# analyte: Pf_LDH, concentration: Hi, temp: 23, base_half: 6011.077499999999, closest_val: [[5998.44570886]], half life: 126
# analyte: Pf_LDH, concentration: Hi, temp: 30, base_half: 6011.077499999999, closest_val: [[6027.7907965]], half life: 29
# analyte: Pf_LDH, concentration: Hi, temp: 50, base_half: 6011.077499999999, closest_val: [[5970.22164393]], half life: 9
# analyte: Pf_LDH, concentration: Med, temp: 4, base_half: 3474.2075, closest_val: [[3540.87371049]], half life: 196
# analyte: Pf_LDH, concentration: Med, temp: 23, base_half: 3474.2075, closest_val: [[3477.91927301]], half life: 126
# analyte: Pf_LDH, concentration: Med, temp: 30, base_half: 3474.2075, closest_val: [[3472.27680331]], half life: 28
# analyte: Pf_LDH, concentration: Med, temp: 50, base_half: 3474.2075, closest_val: [[3503.66903837]], half life: 9
# analyte: Pf_LDH, concentration: Low, temp: 4, base_half: 398.11375, closest_val: [[526.39046414]], half life: 166
# analyte: Pf_LDH, concentration: Low, temp: 23, base_half: 398.11375, closest_val: [[398.84499212]], half life: 135
# analyte: Pf_LDH, concentration: Low, temp: 30, base_half: 398.11375, closest_val: [[397.66089633]], half life: 38
# analyte: Pf_LDH, concentration: Low, temp: 50, base_half: 398.11375, closest_val: [[401.84716224]], half life: 317
# analyte: CRP, concentration: Hi, temp: 4, base_half: 8975.462500000001, closest_val: [[9152.72825778]], half life: 242
# analyte: CRP, concentration: Hi, temp: 23, base_half: 8975.462500000001, closest_val: [[8933.66818773]], half life: 225
# analyte: CRP, concentration: Hi, temp: 30, base_half: 8975.462500000001, closest_val: [[9167.78196174]], half life: 238
# analyte: CRP, concentration: Hi, temp: 50, base_half: 8975.462500000001, closest_val: [[8840.83175328]], half life: 19
# analyte: CRP, concentration: Med, temp: 4, base_half: 3814.1175000000003, closest_val: [[3642.36870245]], half life: 244
# analyte: CRP, concentration: Med, temp: 23, base_half: 3814.1175000000003, closest_val: [[3785.02688612]], half life: 240
# analyte: CRP, concentration: Med, temp: 30, base_half: 3814.1175000000003, closest_val: [[3866.86088037]], half life: 0
# analyte: CRP, concentration: Med, temp: 50, base_half: 3814.1175000000003, closest_val: [[3817.01355899]], half life: 43
# analyte: CRP, concentration: Low, temp: 4, base_half: 349.9125, closest_val: [[349.99483664]], half life: 139
# analyte: CRP, concentration: Low, temp: 23, base_half: 349.9125, closest_val: [[350.73130668]], half life: 109
# analyte: CRP, concentration: Low, temp: 30, base_half: 349.9125, closest_val: [[349.68215949]], half life: 254
# analyte: CRP, concentration: Low, temp: 50, base_half: 349.9125, closest_val: [[362.91871827]], half life: 252

# %%
regr.predict(poly.fit_transform([[301]]))
# Out:
# array([[41.94337935]])

# %%
base_val / 2
# Out:
# 41.851875
