# %%
import pandas as pd
import numpy as np
import math
from functools import partial, reduce
import os
import re

# %%
analyte_name_dict = {'HRP2_pg_ml': ('HRP2', 'pg/ml'), 'LDH_Pan_pg_ml': ('LDH_Pan', 'pg/ml'),
                     'LDH_Pv_pg_ml': ('LDH_Pv', 'pg/ml'), 'LDH_Pf_pg_ml': ('LDH_Pf', 'pg/ml'),
                     'CRP_ng_ml': ('CRP', 'ng/ml')}

# %%
def set_llq_ulq(df, data_col):
    if isinstance(df[data_col], str):
        if '<' in df[data_col]:
            return 0
        elif '>' in df[data_col]:
            return 2
    return 1

# %%
def clean_strings(val):
    if isinstance(val, str):
        clean = val.replace('<', '')
        clean = clean.replace('>', '')
        try:
            return float(clean)
        except ValueError:
            return clean
    return val

# %%
order = ['study_id', 'sample_id', 'participant_id', 'sample_type', 'country', 'lat', 'long', 'age_yrs', 'fever',
         'timepoint_days', 'initial_specimen_category', 'confirmation_via', 'quansys_HRP2_pg_ml', 'quansys_HRP2_result',
         'quansys_HRP2_bin', 'quansys_LDH_Pan_pg_ml', 'quansys_LDH_Pan_result', 'quansys_LDH_Pan_bin',
         'quansys_LDH_Pv_pg_ml', 'quansys_LDH_Pv_result', 'quansys_LDH_Pv_bin', 'quansys_LDH_Pf_pg_ml',
         'quansys_LDH_Pf_result', 'quansys_LDH_Pf_bin', 'quansys_CRP_ng_ml', 'quansys_CRP_result', 'quansys_CRP_bin']

# %%
input_path = 'C:/Users/lzoeckler/Desktop/qfu'
files = [file for file in os.listdir(input_path) if 'csv' in file]
for fname in files:
    print(fname)
    df = pd.read_csv('{}/{}'.format(input_path, fname))
    modified_df = df.copy(deep=True)
    for analyte in analyte_name_dict.keys():
        data_col = 'quansys_{}'.format(analyte)
        name, unit = analyte_name_dict[analyte]
        partial_qs = partial(set_llq_ulq, data_col=data_col)
        modified_df['quansys_{}_bin'.format(name)] = modified_df.apply(partial_qs, axis=1)
        modified_df[data_col] = modified_df[data_col].apply(clean_strings)
    modified_df = modified_df[order]
    modified_df.to_csv('{}/binned/{}'.format(input_path, fname), index=False)
modified_df.head()
# Out:
# formatted_4plex_NIH_clinical.csv
# formatted_4plex_WB_NIH_Pf_SPZ.csv
# formatted_4plex_WB_NIH_Pf_TBV.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-105ed4097dfa> in <module>
#      11         modified_df['quansys_{}_bin'.format(name)] = modified_df.apply(partial_qs, axis=1)
#      12         modified_df[data_col] = modified_df[data_col].apply(clean_strings)
# ---> 13     modified_df = modified_df[order]
#      14     modified_df.to_csv('{}/binned/{}'.format(input_path, fname), index=False)
#      15 modified_df.head()
#
# ~\miniconda3\envs\DIAMETER\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\miniconda3\envs\DIAMETER\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\miniconda3\envs\DIAMETER\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\miniconda3\envs\DIAMETER\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['confirmation_via'] not in index"

# %%
df[['quansys_HRP2_pg_ml']].head()
# Out:
#   quansys_HRP2_pg_ml
# 0           17215.98
# 1        > 492800.00
# 2               3.64
# 3               5.17
# 4               3.37

# %%
modified_df[['quansys_HRP2_pg_ml', 'quansys_HRP2_bins']].head()
# Out:
#    quansys_HRP2_pg_ml  quansys_HRP2_bins
# 0            17215.98                  1
# 1           492800.00                  2
# 2                3.64                  1
# 3                5.17                  1
# 4                3.37                  1

# %%
input_path = 'C:/Users/lzoeckler/Desktop/quansys_formatting'
df = pd.read_csv('{}/formatted_5plex_WB_FIND_Pf_Pv.csv'.format(input_path))
df.head()
# Out:
#    study_id           sample_id  participant_id sample_type  sample_variable  \
# 0        11  MA0070100280001001             NaN          WB              NaN
# 1        11  MA0070100340001001             NaN          WB              NaN
# 2        11  MA0070100360001001             NaN          WB              NaN
# 3        11  MA0070100370001001             NaN          WB              NaN
# 4        11  MA0070100390001001             NaN          WB              NaN
#
#    symptomatic_fever  timepoint  initial_specimen_catagory location   status  \
# 0                NaN        NaN                        NaN  Senegal  febrile
# 1                NaN        NaN                        NaN  Senegal  febrile
# 2                NaN        NaN                        NaN  Senegal  febrile
# 3                NaN        NaN                        NaN  Senegal  febrile
# 4                NaN        NaN                        NaN  Senegal  febrile
#
#    ... quansys_LDH_Pan_pg_ml  quansys_LDH_Pv_pg_ml quansys_LDH_Pf_pg_ml  \
# 0  ...              64128.05                 39.23             59158.61
# 1  ...              85514.00                 58.87              33415.6
# 2  ...            2714957.57                128.72           2833674.39
# 3  ...             144621.28                 17.58            148565.32
# 4  ...               6012.82                  9.07              2304.52
#
#   quansys_CRP_ng_ml  quansys_HRP2_result quansys_LDH_Pan_result  \
# 0            745.89             positive               positive
# 1            345.06             positive               positive
# 2           3326.26             positive               positive
# 3           5517.80             positive               positive
# 4           2077.90             positive               positive
#
#   quansys_LDH_Pv_result quansys_LDH_Pf_result quansys_CRP_result  quansys_type
# 0              negative              positive                NaN         5plex
# 1              negative              positive                NaN         5plex
# 2              negative              positive                NaN         5plex
# 3              negative              positive                NaN         5plex
# 4              negative              positive                NaN         5plex
#
# [5 rows x 21 columns]

# %%
df['sample_variable'] = df['location'].apply(lambda x: 'location: {}'.format(x))
df['symptomatic_fever'] = df['status']
df.head()
# Out:
#    study_id           sample_id  participant_id sample_type  \
# 0        11  MA0070100280001001             NaN          WB
# 1        11  MA0070100340001001             NaN          WB
# 2        11  MA0070100360001001             NaN          WB
# 3        11  MA0070100370001001             NaN          WB
# 4        11  MA0070100390001001             NaN          WB
#
#      sample_variable symptomatic_fever  timepoint  initial_specimen_catagory  \
# 0  location: Senegal           febrile        NaN                        NaN
# 1  location: Senegal           febrile        NaN                        NaN
# 2  location: Senegal           febrile        NaN                        NaN
# 3  location: Senegal           febrile        NaN                        NaN
# 4  location: Senegal           febrile        NaN                        NaN
#
#   location   status  ... quansys_LDH_Pan_pg_ml  quansys_LDH_Pv_pg_ml  \
# 0  Senegal  febrile  ...              64128.05                 39.23
# 1  Senegal  febrile  ...              85514.00                 58.87
# 2  Senegal  febrile  ...            2714957.57                128.72
# 3  Senegal  febrile  ...             144621.28                 17.58
# 4  Senegal  febrile  ...               6012.82                  9.07
#
#   quansys_LDH_Pf_pg_ml quansys_CRP_ng_ml  quansys_HRP2_result  \
# 0             59158.61            745.89             positive
# 1              33415.6            345.06             positive
# 2           2833674.39           3326.26             positive
# 3            148565.32           5517.80             positive
# 4              2304.52           2077.90             positive
#
#   quansys_LDH_Pan_result quansys_LDH_Pv_result quansys_LDH_Pf_result  \
# 0               positive              negative              positive
# 1               positive              negative              positive
# 2               positive              negative              positive
# 3               positive              negative              positive
# 4               positive              negative              positive
#
#   quansys_CRP_result  quansys_type
# 0                NaN         5plex
# 1                NaN         5plex
# 2                NaN         5plex
# 3                NaN         5plex
# 4                NaN         5plex
#
# [5 rows x 21 columns]

# %%
df.drop(['location', 'status'], axis=1, inplace=True)
df.to_csv('{}/formatted_5plex_WB_FIND_Pf_Pv.csv'.format(input_path), index=False)
